# %% [markdown]
# <a href="https://colab.research.google.com/github/shihab-iiuc/ML-Other-Topics-Learning/blob/main/Data_Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Min-Max Normalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler
data={'Feature1':[10,20,15,5],
      'Feature2':[20,30,25,15]
      }

df=pd.DataFrame(data)
print(f"Orginal data:\n{df}")
scaler=MinMaxScaler()
scaler_data=scaler.fit_transform(df)
df_scaled=pd.DataFrame(scaler_data,columns=df.columns)
print(f"Scaled_data:\n{df_scaled}")
# Out:
# Orginal data:
#    Feature1  Feature2
# 0        10        20
# 1        20        30
# 2        15        25
# 3         5        15
# Scaled_data:
#    Feature1  Feature2
# 0  0.333333  0.333333
# 1  1.000000  1.000000
# 2  0.666667  0.666667
# 3  0.000000  0.000000

# %% [markdown]
# # Standardization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
standard=StandardScaler()
s_scaler=standard.fit_transform(df)
s_scaled=pd.DataFrame(s_scaler,columns=df.columns)
print(f"Scaled_data:\n{s_scaled}")
s_scaled.describe()
# Out:
# Scaled_data:
#    Feature1  Feature2
# 0 -0.447214 -0.447214
# 1  1.341641  1.341641
# 2  0.447214  0.447214
# 3 -1.341641 -1.341641
#        Feature1  Feature2
# count  4.000000  4.000000
# mean   0.000000  0.000000
# std    1.154701  1.154701
# min   -1.341641 -1.341641
# 25%   -0.670820 -0.670820
# 50%    0.000000  0.000000
# 75%    0.670820  0.670820
# max    1.341641  1.341641

# %% [markdown]
# ![image.png](data:image/png;base64,...)
